# %% [markdown]
# # Beautiful Soup
#
# Documentation is detailed so follow through it at https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012"
page = requests.get(URL)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<!--\npage generated at: Wed Sep 29 19:54:33 BST 2021\npage generated by escenic.server/hostname: nat-pres104.tm-aws.com/nat-pres104.tm-aws.com\npage generated in section: 41550\n-->\n<head>\n<link rel="dns-prefetch" href="https://s2-prod.irishmirror.ie"><link rel="preconnect" href="https://s2-prod.irishmirror.ie"><link rel="dns-prefetch" href="https://i2-prod.irishmirror.ie"><link rel="preconnect" href="https://i2-prod.irishmirror.ie"><link rel="dns-prefetch" href="https://felix.data.tm-awx.com"><link rel="preconnect" href="https://felix.data.tm-awx.com"><link rel="dns-prefetch" href="https://www.googletagmanager.com"><link rel="preconnect" href="https://www.googletagmanager.com"><link rel="dns-prefetch" href="https://www.google-analytics.com"><link rel="preconnect" href="https://www.google-analytics.com"><link rel="dns-prefetch" href="https://c.go-mpulse.net"><link rel="preconnect" href="https://c.go-mpulse.net"><link rel="dns-prefetch" href="https://quantcast.mgr.consensu.org"><link rel="preconnect" href="https://quantcast.mgr.consensu.org"><link rel="dns-prefetch" href="https://assets-jpcust.jwpsrv.com"><link rel="preconnect" href="https://assets-jpcust.jwpsrv.com"><link rel="dns-prefetch" href="https://cdn.jwplayer.com"><link rel="preconnect" href="https://cdn.jwplayer.com"><link rel="preload" href="https://cdn.jwplayer.com/v2/media/OR1Gxx9u/poster.jpg">\n<link rel="stylesheet" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/marwood/TM/scss/article-base.css?v=d6cdab91c9de10e8f147cf9b68f3912d"><link rel="stylesheet" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-static-html/scss/chameleon-static-html.css?v=719974e232e7c7aca203a52e2b3a135f">\n<link rel="stylesheet" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/marwood/TM/scss/marwood-extended.css?v=01b8bcda6b280ca1708c975a5648b1d4" media="screen and (min-width: 728px)">\n<style type="text/css">.gpt.sticky-bottom-banner{background-color:#F1F1F1;bottom:0;left:0;margin:0 auto;padding:0;position:fixed;width:100%;z-index:5000002}.gpt.sticky-bottom-banner.ssr{height:111px;max-height:111px}@media all and (min-width: 728px){.gpt.sticky-bottom-banner.ssr{display:none}}.gpt.sticky-bottom-banner.ssr-hidden{visibility:hidden}@media only screen and (max-width: 727px){.gpt.top-slot.ssr{align-items:center;display:flex;height:111px;justify-content:center;max-height:111px;max-width:320px}.gpt.top-slot.ssr-hidden{visibility:hidden}.gpt.top-slot.ssr-article{margin:10px auto}.gpt.top-slot.ssr-section{margin:135px auto -33px}.gpt.top-slot.ssr-section.top-slot-wrapper{margin:40px auto 10px}}\n/*# sourceMappingURL=critical.css.map */</style>\n<link rel="stylesheet" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/article-service/scss/core.css?v=ea575a4d12cdb01ab47de17b8cb74d33">\n<meta id="publicationConfig" name="publicationConfig" content="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/publications/irishmirror/"><link rel="preload" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/webfonts/woff2/SignikaNegative-Bold.47b398e81c9f2e2e.woff2" as="font" crossorigin="crossorigin"><link rel="preload" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/webfonts/woff2/opensans-bold-webfont.1b0229cc78352a07.woff2" as="font" crossorigin="crossorigin"><link rel="preload" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/webfonts/woff2/opensans-regular-webfont.c17ed4f560d01e13.woff2" as="font" crossorigin="crossorigin"><link rel="preload" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/webfonts/woff2/icomoon.edbe0dea183769a4.woff2" as="font" crossorigin="crossorigin"><link rel="preload" href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-branding/publications/irishmirror/scss/brand-extended.02ef0f98ef1b0dad.css" as="style"><link rel="stylesheet" href="https://s2-p ...

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# ```<html>
#     <head>
#     keeps the metadata, like date / title of the page
#     </head>
#
#     <body>
#     The greater content
#
#         <div>
#             <p>
#             </p>
#         </div>
#
#     </body>
# </html>```

# %%
soup.body
# Out:
# <body class="article-page news" itemscope="itemscope" itemtype="http://schema.org/NewsArticle">
# <script type="text/javascript">!function(){return function e(t,n,a){function r(i,u){if(!n[i]){if(!t[i]){var c="function"==typeof require&&require;if(!u&&c)return c(i,!0);if(o)return o(i,!0);var d=new Error("Cannot find module '"+i+"'");throw d.code="MODULE_NOT_FOUND",d}var l=n[i]={exports:{}};t[i][0].call(l.exports,function(e){return r(t[i][1][e]||e)},l,l.exports,e,t,n,a)}return n[i].exports}for(var o="function"==typeof require&&require,i=0;i<a.length;i++)r(a[i]);return r}}()({1:[function(e,t,n){"use strict";Object.defineProperty(n,"__esModule",{value:!0});var a=document.documentElement,r={breakpointType:null,overlayActive:!1,resize:{active:!1,debounceTimer:200,interval:null},scroll:{active:!1,debounceTimer:50,interval:null},tapOrClickEvent:"click",throttleDateTime:null,timings:{debounce:250},windowHeight:a.clientHeight,windowTopOffset:null,windowWidth:a.clientWidth};function o(e){for(var t=e.split("."),n=0,a=r;n<t.length;n++)a=a[t[n]];return a}r.breakpoints=[{name:"baseLayout",width:-1},{name:"tabletPortraitUpwards",width:728},{name:"tabletLandscapeUpwards",width:1024},{name:"desktop",width:1240}],n.default={getOption:o,inspect:function(){return r},getBreakpoint:function(e){e=e||window.innerWidth;var t,n=o("breakpoints"),a=n.length;for(t=0;t<a;t++)if(e<n[t].width)return n[t-1].name;return n[a-1].name}}},{}],2:[function(e,t,n){"use strict";Object.defineProperty(n,"__esModule",{value:!0});var a=function(){function e(e){return[].slice.call(e)}var t="DOMContentLoaded";function n(e,t,n,a){if(a=a||{},e.addEventListener(t,n),e.dataEvents){var r=e.dataEvents[t];if(r)if(a.purgeEventData)for(;r.length>0;)n.call(e,{data:r.shift(),target:e});else r.forEach(function(t){n.call(e,{data:t,target:e})})}}function a(e,t,n){e.dataEvents=e.dataEvents||{},e.dataEvents[t]=e.dataEvents[t]||[],e.dataEvents[t].push(n)}return{delegate:function(){return function(t,n,a,r,o){o=o||{},n=n.split(","),void 0===t.length&&(t=[t]),t.forEach||(t=e(t)),t.forEach(function(t){t.addEventListener(a,function(a){var i=[];n.forEach(function(n){i=">"===n.substr(0,1)?function(t,n,a){var r=e(n.querySelectorAll(a.substr(1)));return r=r.filter(function(e){return e.parentNode===n}),t.concat(r)}(i,t,n):function(t,n,a){return t.concat(e(n.querySelectorAll(a)))}(i,t,n)}),function e(t,n,a,r,o,i){if(n!==a){var u=r.indexOf(n);-1!==u&&(o.call(r[u],t),i.preventDefault&&t.preventDefault()),e(t,n.parentNode,a,r,o,i)}else i.stopPropagation&&t.stopPropagation()}(a,a.target,t,i,r,o)})})}}(),domReady:function(e){"complete"===document.readyState||"loaded"===document.readyState?(a(document,t),a(window,"load")):"interactive"===document.readyState&&a(document,t),document.addEventListener?n(document,t,e):n(window,"load",e)},fire:function(e,t,n){var r;n=n||{},document.createEvent?((r=document.createEvent("HTMLEvents")).initEvent(t,!0,!0),r.data=n,e.dispatchEvent(r)):document.createEventObject&&((r=document.createEventObject()).data=n,e.fireEvent("on"+t,r)),a(e,t,n)},listen:n}}();n.default=a},{}],3:[function(e,t,n){"use strict";var a=Object.prototype.hasOwnProperty,r=Object.prototype.toString,o=Object.defineProperty,i=Object.getOwnPropertyDescriptor,u=function(e){return"function"==typeof Array.isArray?Array.isArray(e):"[object Array]"===r.call(e)},c=function(e){if(!e||"[object Object]"!==r.call(e))return!1;var t,n=a.call(e,"constructor"),o=e.constructor&&e.constructor.prototype&&a.call(e.constructor.prototype,"isPrototypeOf");if(e.constructor&&!n&&!o)return!1;for(t in e);return void 0===t||a.call(e,t)},d=function(e,t){o&&"__proto__"===t.name?o(e,t.name,{enumerable:!0,configurable:!0,value:t.newValue,writable:!0}):e[t.name]=t.newValue},l=function(e,t){if("__proto__"===t){if(!a.call(e,t))return;if(i)return i(e,t).value}return e[t]};t.exports=function e(){var t,n,a,r,o,i,f=arguments[0],s=1,p=arguments.length,w=!1;for("boolean"==typeof f&&(w=f,f=arguments[1]||{},s=2),(null==f||"object"!=typeof f&&"function"!=typeof f)&&(f={});s<p;++s)if(null!=(t=arguments[s]))for(n in t)a=l(f,n),f!==(r=l(t,n))&&(w&&r& ...
# //# sourceMappingURL=chameleon-analytics.min.js.map</script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM
by-union/">Rugby</a></li><li><a data-link-tracking="Header|SectionLabel|Text|Travel" href="https://www.irishmirror.ie/lifestyle/travel/">Travel</a></li><li><a data-link-tracking="Header|SectionLabel|Text|Property" href="https://www.irishmirror.ie/lifestyle/homes-and-property/">Property</a></li></ul></section></nav><profile-icon lr-custom-class="header-profile-icon" lr-custom-id="signin" lr-gtm-label="header" lr-show-account-link=""></profile-icon><div class="search"><button aria-label="Search" class="icon icon-search" id="search-icon" type="button"></button></div><div class="search-box hidden"><gcse:searchbox-only resultsurl="https://www.irishmirror.ie/search/"></gcse:searchbox-only></div><div class="social-sites"><ul><li class="follow hidden"><span class="follow-tex ...
# <main>
# <nav class="breadcrumbs breadcrumbs-news"><ol itemscope="" itemtype="http://schema.org/BreadcrumbList"><li class="publication-theme-border" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="publication-theme-highlight publication-theme-icon" data-link-tracking="TopArticle|Subcategories|Home" href="https://www.irishmirror.ie/" itemprop="item"><span itemprop="name">Home</span><meta content="0" itemprop="position"/></a></li><li class="publication-theme-border" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a data-link-tracking="TopArticle|Subcategories|News" href="https://www.irishmirror.ie/news/" itemprop="item"><span itemprop="name">News</span><meta content="1" itemprop="position"/></a></li><li class="publication-theme-border" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a data-link-tracking="TopArticle|Subcategories|Irish News" href="https://www.irishmirror.ie/news/irish-news/" itemprop="item"><span itemprop="name">Irish News</span><meta content="2" itemprop="position"/></a></li><li class="publication-theme-border" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a data-link-tracking="TopArticle|Subcategories|Weather" href="https://www.irishmirror.ie/all-about/weather" itemprop="item"><span itemprop="name">Weather</span><meta content="3" itemprop="position"/></a></li></ol></nav>
# <div itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/NewsMediaOrganization"><meta content="Irish Mirror" itemprop="name"/><meta content="https://www.irishmirror.ie/" itemprop="url"/><div itemprop="logo" itemscope="itemscope" itemtype="https://schema.org/ImageObject"><meta content="https://s3-eu-west-1.amazonaws.com/trinity-images/logos/irishmirror.png" itemprop="url"/><meta content="210" itemprop="width"/><meta content="60" itemprop="height"/></div></div><meta content="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012" itemprop="mainEntityOfPage"/><article class="article-main channel-news" data-converse="" data-mod="articleSso,converse,horizontalSwipe,trackScrollDepth,affiliatetext,axate" data-url="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012"><div class="headline-with-subtype"><div class="article-type publication-font"><a class="channel-name section-theme-highlight" data-link-tracking="TopArticle|MainTag|News" href="https://www.irishmirror.ie/news/">News</a></div><h1 class="section-theme-background-indicator publication-font" itemprop="headline name">Is Ireland in for a freezing October? Met Eireann's forecast for the next 30 days predicts unusual weather</h1></div><p class="sub-title" itemprop="description">October is looking like a very pleasant month according to Met Eireann</p><div class="byline"><div class="sharebar" data-article-id="25088012" data-context="share-bar-25088012" data-friendly-name="Share Bar Link Click" data-max-times-to-track-links="5" data-share-image="https://i2-prod.irishmirror.ie/incoming/article24700745.ece/ALTERNATES/s1200/0_GettyImages-451530710.jpg" data-share-url="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012" data-stream-id="irishmirror-25088012"><a class="hidden" data-link-tracking="Header|MainLogo|Image|irishmirror" href="/" id="logo">irishmirror</a><ul><li class="count-shares"><span class="count-text initial publication-theme">Share</span></li><li class="sharebar-provider"><a class="sharebar-icon icon facebook" data-content-image="https://i2-prod.irishmirror.ie/incoming/article24700745.ece/ALTERNATES/s1200/0_GettyImages-451530710.jpg" data-leadtext="October is looking like a very pleasant month according to Met Eireann" data-provider="facebook" data-social-headline="Met Eireann's forecast for the next 30 days predicts unusual weather" data-tracking="facebook|share|undefined" data-url="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012" title="Facebook"></a><div class="share-filler"></div></li><li class="sharebar-provider"><a class="sharebar-icon icon twitter" data-content-image="https://i2-prod.irishmirror.ie/incoming/article24700745.ece/ALTERNATES/s1200/0_GettyImages-451530710.jpg" data-leadtext="October is looking like a very pleasant month according to Met Eireann" data-provider="twitter" data-social-headline="Met Eireann's forecast for the next 30 days predicts unusual weather" data-tracking="twitter|share|undefined" data-url="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012" title="Twitter"></a><div class="share-filler"></div></li><li class="sharebar-provider"><a class="sharebar-icon icon whatsapp" data-content-image="https://i2-prod.irishmirror.ie/incoming/article24700745.ece/ALTERNATES/s1200/0_GettyImages-451530710.jpg" data-leadtext="October is looking like a very pleasant month according to Met Eireann" data-provider="whatsapp" data-social-headline="Met Eireann's forecast for the next 30 days predicts unusual weather" data-tracking="whatsapp|share|undefined" data-url="https://www.irishmirror.ie/news/irish-news/ireland-freezing-october-met-eireanns-25088012" title="Whatsapp"></a><div class="share-filler"></div></li><li class="copy-link-list"><span class="copy-link brand-bg" data-mod="copyLink" data-url="https://www.irishmirror.ie/news/irish-news/ireland-fr ...
# <meta content="https://i2-prod.irishmirror.ie/incoming/article24882062.ece/ALTERNATES/s615b/0_PA-57836316.jpg" itemprop="url">
# <meta content="615" itemprop="width">
# <meta content="382" itemprop="height">
# <div class="outer">
# <div class="spacer" style="padding-top:62.11%;"></div>
# <div class="mod-image">
# <img alt="People walking on Henry Street in Dublin during wet weather." content="https://i2-prod.irishmirror.ie/incoming/article24882062.ece/ALTERNATES/s615b/0_PA-57836316.jpg" data-src="https://i2-prod.irishmirror.ie/incoming/article24882062.ece/ALTERNATES/s615b/0_PA-57836316.jpg">
# </img></div>
# </div>
# <figcaption class="publication-theme-indicator">
# <span class="caption" itemprop="description">People walking on Henry Street in Dublin during wet weather.</span>
# <span class="credit" itemprop="author"> (Image: NurPhoto/PA Images)</span>
# </figcaption>
# </meta></meta></meta></figure> <h3>Ireland's long-range forecast - from Met Eireann</h3> <p> " <b>Week 1 (Monday 27 September to Sunday 03 October)</b></p> <p>A noticeably cooler and unsettled week ahead than recently with our weather dominated by low pressure to the north feeding in a polar maritime air mass. Temperatures will be below average over the week and rainfall amounts will be above average throughout the country, especially over the western half of the country. Blustery conditions are likely at times, rainfall warnings are possible and there is the chance of thunderstorm activity.</p> <p><b>Week 2 (Monday 04 October to Sunday 10 October)</b></p> <p>Becoming milder for Week 2 with a southwesterly airflow dominating due to high pressure to the south and low pressure to the northwest. Temperatures will likely be above average, especially in the east of the country. However, rain and showers are still likely and much of the country could see above average rainfall amounts but more average amounts in the east and northeast. Rainfall warnings couldn’t be ruled out.</p> <p><b>Week 3 (Monday 11 October to Sunday 17 October)</b></p> <p>Continuing warmer than average in Week 3 with high pressure to the south building up a bit closer to Ireland with the low pressure declining northwards with a southwesterly airflow still predominant. The west and northwest could see above average rainfall with drier than average conditions in the south and east. Lower risk of hazardous rainfall amounts than previously.</p> <p><b>Week 4 (Monday 18 October to Sunday 24 October)</b></p> <p>A less clear signal for Week 4 with a possible weak northeasterly airflow developing with low pressure to the northwest. Temperatures will likely be around average for the time of year and rainfall amounts will likely be below normal for much of the country though showers feeding in from the Irish Sea could see more normal amounts for eastern and northeastern coasts. No clear signal for hazardous conditions though fog could be a feature of the nights.</p> <reach-mpu class="ad-placeholder ad-placeholder--mpu ad-placeholder--in-article ad-placeholder--above-embed" data-ad-unit="mpu"> <div class="ad-placeholder__inner"></div> </reach-mpu> <reach-adyoulike class="ad-placeholder ad-placeholder--adyoulike ad-placeholder--in-article ad-placeholder--above-embed" data-ad-unit="adyoulike"> <div class="ad-placeholder__inner"></div> </reach-adyoulike> <section data-ad-dockable="true" data-embed-group="read-more" data-embed-items="2" data-istail="true" data-redesign-embed="true"> <aside class="read-more-links" data-immediate="" data-mod="readMoreTweak">
# <h5 class="publication-theme-icon publication-theme-border">Read More</h5>
# <h5 class="hidden related-articles publication-theme-icon publication-font">Related Articles</h5>
# <ul>
# <li><a aria-label="Met Eireann's updated forecast shows clear midweek sunshine for some regions" class="embed-image hidden" data-link-tracking="InArticle|Rec|ReadMore|index1|Image" href="https://www.irishmirror.ie/news/met-eireanns-updated-forecast-shows-25086655">
# <figure data-mod="image">
# <img alt="Met Eireann's updated forecast shows clear midweek sunshine for one region" data-src="https://i2-prod.irishmirror.ie/incoming/article25086657.ece/ALTERNATES/s615/0_PA-50800300.jpg">
# </img></figure></a><a data-image="https://i2-prod.irishmirror.ie/incoming/article25086657.ece/ALTERNATES/s615/0_PA-50800300.jpg" data-link-tracking="InArticle|Rec|ReadMore|index1|text" href="https://www.irishmirror.ie/news/met-eireanns-updated-forecast-shows-25086655">Met Eireann's updated forecast shows clear midweek sunshine for some regions</a><img alt="irishmirror" class="embed-image hidden related-publication-logo" src="https://s2-prod.mirror.co.uk/@trinitymirrordigital/chameleon-branding/publications/irishmirror/img/logo-schema-irishmirror.png"/></li>
# </ul>
# </aside> <aside class="read-more-links" data-immediate="" data-mod="readMoreTweak">
# <h5 class="publication-theme-icon publication-theme-border">Read More</h5>
# <h5 class="hidden related-articles publication-theme-icon publication-font">Related Articles</h5>
# <ul>
# <li><a aria-label="Ireland weather: Met Eireann forecast big change as 'polar air mass' to bring drop in temperatures" class="embed-image hidden" data-link-tracking="InArticle|Rec|ReadMore|index2|Image" href="https://www.irishmirror.ie/news/irish-news/ireland-weather-met-eireann-forecast-25082868">
# <figure data-mod="image">
# <img alt="There could be a temperature drop on the way." data-src="https://i2-prod.irishmirror.ie/incoming/article25005906.ece/ALTERNATES/s615/0_PA-57366631.jpg"/>
# </figure></a><a data-image="https://i2-prod.irishmirror.ie/incoming/article25005906.ece/ALTERNATES/s615/0_PA-57366631.jpg" data-link-tracking="InArticle|Rec|ReadMore|index2|text" href="https://www.irishmirror.ie/news/irish-news/ireland-weather-met-eireann-forecast-25082868">Ireland weather: Met Eireann forecast big change as 'polar air mass' to bring drop in temperatures</a><img alt="irishmirror" class="embed-image hidden related-publication-logo" src="https://s2-prod.mirror.co.uk/@trinitymirrordigital/chameleon-branding/publications/irishmirror/img/logo-schema-irishmirror.png"/></li>
# </ul>
# </aside> </section> <reach-taboola class="ad-placeholder ad-placeholder--taboola ad-placeholder--in-article ad-placeholder--below-embed" data-ad-unit="taboola"> <div class="ad-placeholder__inner"></div> </reach-taboola> <reach-converse class="ad-placeholder ad-placeholder--converse ad-placeholder--in-article ad-placeholder--below-embed" data-ad-unit="converse"> <div class="ad-placeholder__inner"></div> </reach-converse> <reach-adyoulike class="ad-placeholder ad-placeholder--adyoulike ad-placeholder--in-article ad-placeholder--below-embed" data-ad-unit="adyoulike"> <div class="ad-placeholder__inner"></div> </reach-adyoulike><!-- Article End--></div><div data-mod="socialFollow" id="social-follow"><div class="call-to-action-bar"><div class="follow-us">Follow <span class="page-name">Irish Mirror</span></div><div class="social-actions"><div class="social-links"><a class="cta-button facebook-button" href="https://www.facebook.com/irishmirror" target="_blank"><span class="cta-icon cta-facebook"></span><span class="cta-label">Facebook</span></a><a class="cta-button twitter-share" href="https://twitter.com/intent/follow?screen_name=irishmirror" target="_blank"><span class="cta-icon cta-twitter"></span><span class="cta-label">Twitter</span></a><div class="cta-break-line"></div></div><div class="comment-link"><a class="add-comment cta-button cta-bar-comment-button" href="#comments-wrapper"><span class="cta-icon cta-comment"><svg fill="none" height="12" viewbox="0 0 13 12" width="13" xmlns="http://www.w3.org/2000/svg">
# <path class="cta-bar-svg" d="M10.7266 2.61544C10.7266 2.15006 10.3501 1.76929 9.88467 1.76929H3.11544C2.65006 1.76929 2.26929 2.15006 2.26929 2.61544V7.69236C2.26929 8.15775 2.65006 8.53852 3.11544 8.53852H9.03852L10.7308 10.2308L10.7266 2.61544Z"></path>
# </svg></span><span class="cta-label">Comment</span><span class="cta-count-num"></span></a></div></div></div></div><div id="comments-wrapper"><div class="viafoura" id="comments-standalone-mpu"><vf-standalone-ad></vf-standalone-ad></div><div class="viafoura notification-tray-enabled" data-mod="viafouraComments" id="comments-section"><vf-conversations limit="4" pagination-limit="5" reply-limit="1"></vf-conversations></div></div><div class="tag-list"><span class="publication-theme-border publication-theme-icon">More On</span><ul><li><a class="publication-theme-button-highlight" data-link-tracking="EndArticle|Tag" href="https://www.irishmirror.ie/all-about/met-eireann">Met Eireann</a></li><li><a class="publication-theme-button-highlight" data-link-tracking="EndArticle|Tag" href="https://www.irishmirror.ie/all-about/weather">Weather</a></li></ul></div></div><aside class="related-column secondary"></aside></div></article>
# <!-- start of widget id: 8708042, name: recirculationTeasers, view: mostReadAndMostRecent, start time: 1632940420809 -->
# <section data-immediate="" data-mod="mostRead"><div class="pancake publication-theme"><div data-ignore="" data-mod="tabs"><ul class="tab-triggers section-theme-border"><li><button data-active-class="section-theme-gradient" data-class="channel-news" data-tabset="mostReadMostRecent" data-value="news">News</button></li><li><button data-active-class="section-theme-gradient" data-class="channel-all" data-tabset="mostReadMostRecent" data-value="all">all</button></li></ul><div class="tab-content section-theme-inherit-background-indicator" data-ignore="" data-mod="tabs" data-tabset="mostReadMostRecent" data-value="news"><ul class="tab-triggers"><li><button class="section-theme-border" data-tabset="news" data-value="mostRead">Most Read</button></li><li><button class="section-theme-border" data-tabset="news" data-value="mostRecent">Most Recent</button></li></ul><div class="tab-content" data-tabset="news" data-value="mostRead"><div class="pancake use-image-placeholders ensemble" data-group="mostRead" data-group-index="0"><div class="teaser teaser-highlight"><figure class="section-theme-border" data-mod="image"><a aria-label="Australian judge tells Irishman to 'take your stupid Irishness' elsewhere as he bans him from bar after fight" data-link-tracking="PostArticle|Rec|news|mostRead|image|index 1" href="https://www.irishmirror.ie/news/irish-news/crime/australian-judge-tells-irishman-take-25090591"><img alt="" data-src="https://i2-prod.irishmirror.ie/incoming/article25090956.ece/ALTERNATES/s615/0_sadasdadasdJPG.jpg" src="/@trinitymirrordigital/marwood/TM/img/placeholders/transparent.png"/></a></figure><a class="label section-theme-highlight" data-link-tracking="PostArticle|News|MostRecent|Tag|Fire|index 1" href="https://www.irishmirror.ie/all-about/courts">Courts</a><a class="headline publication-font" data-link-tracking="PostArticle|Rec|news|mostRead|title|index 1" href="https://www.irishmirror.ie/news/irish-news/crime/australian-judge-tells-irishman-take-25090591">Australian judge tells Irishman to 'take your stupid Irishness' elsewhere as he bans him from bar after fight</a><a class="description" data-link-tracking="undefineddescriptionundefined" href="https://www.irishmirror.ie/news/irish-news/crime/australian-judge-tells-irishman-take-25090591">The Irishman attempted to fight multiple pub patrons while out celebrating his 27th birthday in Queensland, Australia</a></div><div class="pancake duet secondary"><div class="teaser"><figure data-mod="image"><a aria-label="Date proposed for Ireland's new bank holiday and it's just weeks away" data-link-tracking="PostArticle|Rec|news|mostRead|image|index 2" href="https://www.irishmirror.ie/news/irish-news/date-proposed-irelands-new-bank-25087030"><img alt="" data-src="https://i2-prod.irishmirror.ie/incoming/article25084951.ece/ALTERNATES/s615/1_CC-REOPENINGS-_3390499357.jpg" data-srcset="https://i2-prod.irishmirror.ie/incoming/article25084951.ece/ALTERNATES/s180/1_CC-REOPENINGS-_3390499357.jpg 180w, https://i2-prod.irishmirror.ie/incoming/article25084951.ece/ALTERNATES/s458/1_CC-REOPENINGS-_3390499357.jpg 458w" src="/@trinitymirrordigital/marwood/TM/img/placeholders/transparent.png"/></a><div class="video-icon section-theme-border section-theme"></div></figure><a class="headline" data-link-tracking="PostArticle|Rec|news|mostRead|title|index 2" href="https://www.irishmirror.ie/news/irish-news/date-proposed-irelands-new-bank-25087030">Date proposed for Ireland's new bank holiday and it's just weeks away</a><div class="label-line"><a class="label" data-link-tracking="PostArticle|Rec|news|mostRead|Tag|Fire|index 2" href="https://www.irishmirror.ie/all-about/leo-varadkar">Leo Varadkar</a><a class="description" data-link-tracking="undefineddescriptionundefined" href="https://www.irishmirror.ie/news/irish-news/date-proposed-irelands-new-bank-25087030">This ties in with a new study by Fáilte Ireland which estimates that a bonus Bank Holiday could generate up to €20million</a></div></div><div class="tea ...
# <!-- end of widget id: 8708042, name: recirculationTeasers, view: mostReadAndMostRecent, total time: 3 -->
# <section class="top-stories section-theme-border"><div class="headline"><a class="publication-theme-indicator publication-font publication-theme-hover" href="/">Top Stories</a></div><div class="pancake use-image-placeholders quartet" data-group="topStories" data-group-index="0"><div class="teaser"><figure data-mod="image"><a aria-label="LIVE Irish Lotto results: Tonight's winning numbers in record €19 million jackpot draw" data-link-tracking="PostArticle|Rec|live-event|topStories|image|index 1" href="https://www.irishmirror.ie/news/irish-news/live-irish-lotto-results-tonights-25102607"><img alt="" data-src="https://i2-prod.irishmirror.ie/incoming/article25102657.ece/ALTERNATES/s615/0_pjimage-2.jpg" data-srcset="https://i2-prod.irishmirror.ie/incoming/article25102657.ece/ALTERNATES/s180/0_pjimage-2.jpg 180w, https://i2-prod.irishmirror.ie/incoming/article25102657.ece/ALTERNATES/s220b/0_pjimage-2.jpg 220w, https://i2-prod.irishmirror.ie/incoming/article25102657.ece/ALTERNATES/s270b/0_pjimage-2.jpg 270w" src="/@trinitymirrordigital/marwood/TM/img/placeholders/transparent.png"/></a><em class="live-identifier publication-theme-background-indicator">Live-event</em></figure><a class="headline" data-link-tracking="PostArticle|Rec|live-event|topStories|title|index 1" href="https://www.irishmirror.ie/news/irish-news/live-irish-lotto-results-tonights-25102607">LIVE Irish Lotto results: Tonight's winning numbers in record €19 million jackpot draw</a><div class="label-line"><a class="label" data-link-tracking="PostArticle|Rec|live-event|topStories|Tag|Fire|index 1" href="https://www.irishmirror.ie/all-about/lotto">Lotto</a><a class="description" data-link-tracking="undefineddescriptionundefined" href="https://www.irishmirror.ie/news/irish-news/live-irish-lotto-results-tonights-25102607">Lotto fever is gripping the country ahead of the highest ever draw</a></div></div><div class="teaser"><figure data-mod="image"><a aria-label="Nurses say single bank holiday won't be accepted as they demand extra pay or leave in pandemic bonus stand-off" data-link-tracking="PostArticle|Rec|news|topStories|image|index 2" href="https://www.irishmirror.ie/news/irish-news/politics/nurses-say-single-bank-holiday-25102093"><img alt="" data-src="https://i2-prod.irishmirror.ie/incoming/article25102165.ece/ALTERNATES/s615/0_Citywest-Vaccine-Centre2190505185.jpg" data-srcset="https://i2-prod.irishmirror.ie/incoming/article25102165.ece/ALTERNATES/s180/0_Citywest-Vaccine-Centre2190505185.jpg 180w, https://i2-prod.irishmirror.ie/incoming/article25102165.ece/ALTERNATES/s220b/0_Citywest-Vaccine-Centre2190505185.jpg 220w, https://i2-prod.irishmirror.ie/incoming/article25102165.ece/ALTERNATES/s270b/0_Citywest-Vaccine-Centre2190505185.jpg 270w" src="/@trinitymirrordigital/marwood/TM/img/placeholders/transparent.png"/></a></figure><a class="headline" data-link-tracking="PostArticle|Rec|news|topStories|title|index 2" href="https://www.irishmirror.ie/news/irish-news/politics/nurses-say-single-bank-holiday-25102093">Nurses say single bank holiday won't be accepted as they demand extra pay or leave in pandemic bonus stand-off</a><div class="label-line"><a class="label" data-link-tracking="PostArticle|Rec|news|topStories|Tag|Fire|index 2" href="https://www.irishmirror.ie/all-about/irish-nurses-and-midwives-organisation">Irish Nurses and Midwives Organisation</a><a class="description" data-link-tracking="undefineddescriptionundefined" href="https://www.irishmirror.ie/news/irish-news/politics/nurses-say-single-bank-holiday-25102093">The INMO said if the Government is looking at another bank holiday then 'that is an issue that is separate to the issue we are raising'</a></div></div><div class="teaser"><figure data-mod="image"><a aria-label="Killer police officer Wayne Couzens handcuffed and 'arrested' Sarah Everard in fake Covid patrol before he raped and murdered her, court hears" data-link-tracking="PostArticle|Rec|news|topStories|image|index 3" href="https://www.irishmirror.ie/news ...
# <div class="container"><div class="related-stories read-next section-theme-border brand-hint-bg" data-channel="tagsFallback" data-condition-node="#outbrainFooterArticleSlot" data-immediate="data-immediate" data-items="3" data-layout="baseLayout tabletPortraitUpwards tabletLandscapeUpwards desktop" data-mod="renderRecommendation" data-read-next-type="RelatedArticles" data-rec-title="Related Articles" data-refnode=".article-body"></div><div class="dont-miss read-next brand-hint-bg" data-channel="collaborative" data-condition-node=".article-body &gt; p:nth-of-type(18)" data-immediate="data-immediate" data-items="3" data-layout="baseLayout tabletPortraitUpwards" data-mod="renderRecommendation" data-read-next-type="DontMiss" data-rec-title="Don’t miss" data-refnode="#div-gpt-ad-in-article-slot-long"></div><div class="whats-hot read-next brand-hint-bg" data-channel="mostReadChannel" data-condition-node=".article-body &gt; p:nth-of-type(11)" data-immediate="data-immediate" data-items="3" data-layout="baseLayout tabletPortraitUpwards" data-mod="renderRecommendation" data-read-next-type="WhatsHot" data-rec-title="Most Read" data-refnode="#div-gpt-ad-in-article-slot"></div><div class="whats-hot read-next brand-hint-bg" data-channel="mostReadChannel" data-immediate="data-immediate" data-items="5" data-layout="tabletLandscapeUpwards desktop" data-mod="renderRecommendation" data-read-next-type="WhatsHot" data-rec-title="Most Read" data-refnode="#div-gpt-ad-rh-slot"></div></div>
# </main>
# <script type="text/javascript">$css("https://s2-prod.irishmirror.ie/@trinitymirrordigital/withnail/scss/withnail.css?v=db9ee2ec0f4ea8436e38580f202ee38b");$css("https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-partnership-widgets/scss/partners.css?v=327d40d656ed22a2e99b5a7df2a3716d");$css("https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-video/scss/video.css?v=6553334477ddec56063fbd0d505b62d0");</script>
# <script src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/dragonfly/b8ee3f296778fd85df20afef2021d7df92ff12bc/core-components/observer.js" type="module"></script>
# <script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/marwood/TM/js/article.min.js?v=94d392831d14ec1645b6207ff789cbe6"></script><script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-video/js/video.min.js?v=cd781b34d60af537cf007bbbc479e9a7"></script><script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/article-service/js/article-service.min.js?v=c70dbd1680dddd32a79ce59cd7283569"></script><script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-partnership-widgets/js/partner.min.js?v=e10faacadc386185451f89c49ba2ae58"></script><script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/chameleon-static-html/js/chameleon-static-html.min.js?v=a62d206cab4f05b1dfc3eef728ca5c21"></script>
# <script defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/withnail/scriptsCore/js/withnail.min.js?v=ada3b237e14bb100a6282daf6ec35aaa"></script>
# <script async="" defer="" src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/article-service/read-next/js/render-recommendations.min.js?v=b3b255b50522ca847969671c0f17de19"></script>
# <div class="widget code html widget-editable viziwyg-section-22362 inpage-widget-11418709">
# <script async="" src="https://felix.data.tm-awx.com/felix.min.js"></script>
# </div>
# <script>
# var publicSectionParams = window.TMCONFIG.publicSectionParams;
# var environment = 'digitalData.page.attributes.environment'.split('.').reduce(function(acc,cur) { return acc && acc[cur] || undefined; }, window);
# if (environment === 'prod' && publicSectionParams['hotjar.hjid']) {
# (function(h,o,t,j,a,r){
# h.hj=h.hj||function()
# {(h.hj.q=h.hj.q||[]).push(arguments)}
# ;
# h._hjSettings={hjid:publicSectionParams['hotjar.hjid'],hjsv:6};
# a=o.getElementsByTagName('head')[0];
# r=o.createElement('script');r.async=1;
# r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# }
# </script>
# <script>
# window.console.log("iPhone/Edge Fix running...");
# (function (doc) {
# var agnt = navigator.userAgent;
# var css = ".captify-widget>div>div>div{padding-bottom:30px!important}";
# var count = 300; // 300 * 100ms == 30000ms limit
# function isIphone() {
# return /iPhone/.test(agnt);
# }
# function isEdge() {
# return /Edge/.test(agnt);
# }
# function isEdgeOrIphone() {
# return isIphone() || isEdge();
# }
# function applyFix() {
# var ifr = doc.querySelector(".captify-iframe");
# if (ifr && isEdge(agnt)) {
# fixEdge(ifr);
# } else if (ifr && ifr.contentDocument && ifr.contentDocument.head && isIphone(agnt)) {
# fixIphone(ifr.contentDocument);
# } else {
# count--;
# if (count) {
# setTimeout(applyFix, 100);
# }
# }
# }
# function fixIphone(doc) {
# var styleTag = doc.createElement("style");
# styleTag.type = "text/css";
# styleTag.appendChild(doc.createTextNode(css));
# styleTag.cssText = doc.head.appendChild(styleTag);
# }
# function fixEdge(ifr) {
# if (ifr.contentDocument && ifr.contentDocument.childNodes && ifr.contentDocument.childNodes.length) {
# //finished
# } else {
# ifr.classList.add("hidden");
# count = 100; // 100 * 50ms == 5000ms limit
# setTimeout(unhideEdge, 50, ifr);
# }
# }
# function unhideEdge(ifr){
# if (ifr.contentDocument && ifr.contentDocument.childNodes && ifr.contentDocument.childNodes.length) {
# ifr.classList.remove("hidden");
# } else {
# count--;
# if (count) {
# setTimeout(unhideEdge, 50, ifr);
# }
# }
# }
# if (isEdgeOrIphone()) {
# applyFix();
# }
# })(document);
# </script>
# <div data-immediate="" data-mod="geoblock" id="geoblocker-placeholder"></div>
# <div class="lazy-resources" data-css="[]" data-immediate="" data-js="[]" data-mod="lazyResources"></div>
# <script data-url="https://s2-prod.irishmirror.ie/@trinitymirrordigital/breaking-news-client/5bf64e1cfaf573043b28302497d4a60ac9455faa/pull.js" id="breaking-news-loader">window.addEventListener('load', function() {
# setTimeout(function() {
# ["https://s2-prod.irishmirror.ie/@trinitymirrordigital/breaking-news-client/5bf64e1cfaf573043b28302497d4a60ac9455faa/pull.js"].forEach(file => {const el=document.createElement('SCRIPT');el.setAttribute('src', file);el.setAttribute('type', 'module');document.body.appendChild(el);});
# }, 3000);
# });</script>
# <link href="https://s2-prod.irishmirror.ie/@trinitymirrordigital/user-profile/4e040e5337acf4e9a98814000980447390a2bb64/style.css" rel="stylesheet"/><script src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/user-profile/4e040e5337acf4e9a98814000980447390a2bb64/index.js"></script>
# <script src="https://s2-prod.irishmirror.ie/@trinitymirrordigital/auth-ui/auth-ui.min.js?v=fa181fd1eda126b0331c0082dca1954b"></script>
# <div class="widget code html widget-editable viziwyg-section-22293 inpage-widget-23585499">
# <script defer="" src="https://reach-id.orbit.tm-awx.com/analytics.js.gz"></script>
# </div>
# </body>

# %%
soup.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\nIs Ireland in for a freezing October? Met Eireann\'s forecast for the next 30 days predicts unusual weather - Irish Mirror Online\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nirishmirrorLoad mobile navigationNewsLatest NewsIrish NewsCrimePoliticsEducationWorld NewsNews OpinionExpandSportLatest SportGAASoccerGolfRugby UnionUFCOther SportSport OpinionExpandShowbizTV & FilmLifestyleGAARugbyTravelPropertyFollow usLotto ResultsBingoHoroscopesCrosswordsMarketplaceNewsletter signupAbout UsAdvertise with usContact UsWork for usCorrections & ClarificationsGoogle SurveyCookie NoticePrivacy NoticeTerms and ConditionsHow to ComplainNewsletter SignupSyndication & LicensingMirror.co.ukBelfastLive.co.uk© 2021 MGN Limited\n\nHomeNewsIrish NewsWeather\nNewsIs Ireland in for a freezing October? Met Eireann\'s forecast for the next 30 days predicts unusual weatherOctober is looking like a very pleasant month according to Met EireannirishmirrorShare\xa0CommentsByCormac O\'Shea10:12, 28 SEP 2021NewsVideo LoadingVideo UnavailableClick to playTap to playThe video will auto-play soon8CancelPlay nowGet daily headlines and breaking news alerts for FREE by signing up to our newsletterInvalid EmailSomething went wrong, please try again later.Sign up!We use your sign-up to provide content in ways you\'ve consented to and to improve our understanding of you. This may include adverts from us and 3rd parties based on our understanding. You can unsubscribe at any time.More infoThank you for subscribingWe have more newslettersShow meSee ourprivacy noticeIreland\'s weather is set to be unusually warm in October with two weeks of above average temperature forecast. The country is feeling the cold this week after a return to more autumnal weather but unseasonable warmth could be back in little over a week. From next Monday, weather chiefs are expecting the lift in temperatures although there is likely to be plenty of rain around too. But that\'s after the rest of this week continues to be cool thanks to low pressure which is bringing in a "polar maritime air mass". Here\'s what to expect from Met Eireann\'s long-range forecast; \n\n\n\n\n\n\n\n\n\n\nPeople walking on Henry Street in Dublin during wet weather.\n (Image: NurPhoto/PA Images)\n\n Ireland\'s long-range forecast - from Met Eireann  " Week 1 (Monday 27 September to Sunday 03 October) A noticeably cooler and unsettled week ahead than recently with our weather dominated by low pressure to the north feeding in a polar maritime air mass. Temperatures will be below average over the week and rainfall amounts will be above average throughout the country, especially over the western half of the country. Blustery conditions are likely at times, rainfall warnings are possible and there is the chance of thunderstorm activity. Week 2 (Monday 04 October to Sunday 10 October) Becoming milder for Week 2 with a southwesterly airflow dominating due to high pressure to the south and low pressure to the northwest. Temperatures will likely be above average, especially in the east of the country. However, rain and showers are still likely and much of the country could see above average rainfall amounts but more average amounts in the east and northeast. Rainfall warnings couldn’t be ruled out. Week 3 (Monday 11 October to Sunday 17 October) Continuing warmer than average in Week 3 with high pressure to the south building up a bit closer to Ireland with the low pressure declining northwards with a southwesterly airflow still predominant. The west and northwest could see above average rainfall with drier than average conditions in the south and east. Lower risk of hazardous rainfall amounts than previously. Week 4 (Monday 18 October to Sunday 24 October) A less clear signal for Week 4 with a possible weak northeasterly airflow developing with low pressure to the northwest. Temperatures will likely be around average for the time of year and rainfall amoun ...

# %%
soup.body.text
# Out:
# '\n\n\nirishmirrorLoad mobile navigationNewsLatest NewsIrish NewsCrimePoliticsEducationWorld NewsNews OpinionExpandSportLatest SportGAASoccerGolfRugby UnionUFCOther SportSport OpinionExpandShowbizTV & FilmLifestyleGAARugbyTravelPropertyFollow usLotto ResultsBingoHoroscopesCrosswordsMarketplaceNewsletter signupAbout UsAdvertise with usContact UsWork for usCorrections & ClarificationsGoogle SurveyCookie NoticePrivacy NoticeTerms and ConditionsHow to ComplainNewsletter SignupSyndication & LicensingMirror.co.ukBelfastLive.co.uk© 2021 MGN Limited\n\nHomeNewsIrish NewsWeather\nNewsIs Ireland in for a freezing October? Met Eireann\'s forecast for the next 30 days predicts unusual weatherOctober is looking like a very pleasant month according to Met EireannirishmirrorShare\xa0CommentsByCormac O\'Shea10:12, 28 SEP 2021NewsVideo LoadingVideo UnavailableClick to playTap to playThe video will auto-play soon8CancelPlay nowGet daily headlines and breaking news alerts for FREE by signing up to our newsletterInvalid EmailSomething went wrong, please try again later.Sign up!We use your sign-up to provide content in ways you\'ve consented to and to improve our understanding of you. This may include adverts from us and 3rd parties based on our understanding. You can unsubscribe at any time.More infoThank you for subscribingWe have more newslettersShow meSee ourprivacy noticeIreland\'s weather is set to be unusually warm in October with two weeks of above average temperature forecast. The country is feeling the cold this week after a return to more autumnal weather but unseasonable warmth could be back in little over a week. From next Monday, weather chiefs are expecting the lift in temperatures although there is likely to be plenty of rain around too. But that\'s after the rest of this week continues to be cool thanks to low pressure which is bringing in a "polar maritime air mass". Here\'s what to expect from Met Eireann\'s long-range forecast; \n\n\n\n\n\n\n\n\n\n\nPeople walking on Henry Street in Dublin during wet weather.\n (Image: NurPhoto/PA Images)\n\n Ireland\'s long-range forecast - from Met Eireann  " Week 1 (Monday 27 September to Sunday 03 October) A noticeably cooler and unsettled week ahead than recently with our weather dominated by low pressure to the north feeding in a polar maritime air mass. Temperatures will be below average over the week and rainfall amounts will be above average throughout the country, especially over the western half of the country. Blustery conditions are likely at times, rainfall warnings are possible and there is the chance of thunderstorm activity. Week 2 (Monday 04 October to Sunday 10 October) Becoming milder for Week 2 with a southwesterly airflow dominating due to high pressure to the south and low pressure to the northwest. Temperatures will likely be above average, especially in the east of the country. However, rain and showers are still likely and much of the country could see above average rainfall amounts but more average amounts in the east and northeast. Rainfall warnings couldn’t be ruled out. Week 3 (Monday 11 October to Sunday 17 October) Continuing warmer than average in Week 3 with high pressure to the south building up a bit closer to Ireland with the low pressure declining northwards with a southwesterly airflow still predominant. The west and northwest could see above average rainfall with drier than average conditions in the south and east. Lower risk of hazardous rainfall amounts than previously. Week 4 (Monday 18 October to Sunday 24 October) A less clear signal for Week 4 with a possible weak northeasterly airflow developing with low pressure to the northwest. Temperatures will likely be around average for the time of year and rainfall amounts will likely be below normal for much of the country though showers feeding in from the Irish Sea could see more normal amounts for eastern and northeastern coasts. No clear signal for hazardous conditions though fog could be a feature of  ...

# %%
soup.p
# Out:
# <p class="sub-title" itemprop="description">October is looking like a very pleasant month according to Met Eireann</p>

# %%
'''
<a href='link'> </a>
'''

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# #
# https://www.irishmirror.ie/news/
# https://www.irishmirror.ie/news/
# https://www.irishmirror.ie/news/irish-news/
# https://www.irishmirror.ie/news/irish-news/crime/
# https://www.irishmirror.ie/news/irish-news/politics/
# https://www.irishmirror.ie/news/irish-news/education/
# https://www.irishmirror.ie/news/world-news/
# https://www.irishmirror.ie/news/news-opinion/
# #
# https://www.irishmirror.ie/sport/
# https://www.irishmirror.ie/sport/
# https://www.irishmirror.ie/sport/gaa/
# https://www.irishmirror.ie/sport/soccer/
# https://www.irishmirror.ie/sport/golf/
# https://www.irishmirror.ie/sport/rugby-union/
# https://www.irishmirror.ie/sport/ufc/
# https://www.irishmirror.ie/sport/other-sport/
# https://www.irishmirror.ie/sport/sport-opinion/
# #
# https://www.irishmirror.ie/showbiz/
# https://www.irishmirror.ie/tv/
# https://www.irishmirror.ie/lifestyle/
# https://www.irishmirror.ie/sport/gaa/
# https://www.irishmirror.ie/sport/rugby-union/
# https://www.irishmirror.ie/lifestyle/travel/
# https://www.mirrorpix.com
# https://www.mirror.co.uk/
# https://www.belfastlive.co.uk/
# https://www.irishmirror.ie/

# %%
for link in soup.find_all('p'):
    print(link.text)
# Out:
# October is looking like a very pleasant month according to Met Eireann
# Get daily headlines and breaking news alerts for FREE by signing up to our newsletter
# Ireland's weather is set to be unusually warm in October with two weeks of above average temperature forecast.
# The country is feeling the cold this week after a return to more autumnal weather but unseasonable warmth could be back in little over a week.
# From next Monday, weather chiefs are expecting the lift in temperatures although there is likely to be plenty of rain around too.
# But that's after the rest of this week continues to be cool thanks to low pressure which is bringing in a "polar maritime air mass".
# Here's what to expect from Met Eireann's long-range forecast;
#  " Week 1 (Monday 27 September to Sunday 03 October)
# A noticeably cooler and unsettled week ahead than recently with our weather dominated by low pressure to the north feeding in a polar maritime air mass. Temperatures will be below average over the week and rainfall amounts will be above average throughout the country, especially over the western half of the country. Blustery conditions are likely at times, rainfall warnings are possible and there is the chance of thunderstorm activity.
# Week 2 (Monday 04 October to Sunday 10 October)
# Becoming milder for Week 2 with a southwesterly airflow dominating due to high pressure to the south and low pressure to the northwest. Temperatures will likely be above average, especially in the east of the country. However, rain and showers are still likely and much of the country could see above average rainfall amounts but more average amounts in the east and northeast. Rainfall warnings couldn’t be ruled out.
# Week 3 (Monday 11 October to Sunday 17 October)
# Continuing warmer than average in Week 3 with high pressure to the south building up a bit closer to Ireland with the low pressure declining northwards with a southwesterly airflow still predominant. The west and northwest could see above average rainfall with drier than average conditions in the south and east. Lower risk of hazardous rainfall amounts than previously.
# Week 4 (Monday 18 October to Sunday 24 October)
# A less clear signal for Week 4 with a possible weak northeasterly airflow developing with low pressure to the northwest. Temperatures will likely be around average for the time of year and rainfall amounts will likely be below normal for much of the country though showers feeding in from the Irish Sea could see more normal amounts for eastern and northeastern coasts. No clear signal for hazardous conditions though fog could be a feature of the nights.

# %%
# !pip install newspaper3k
# Out:
# Requirement already satisfied: pip in c:\users\nroy0\anaconda3\lib\site-packages (20.2.4)
# Collecting install
#   Downloading install-1.3.4-py3-none-any.whl (3.1 kB)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (5.3.1)
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
# Collecting cssselect>=0.9.2
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (4.9.1)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (8.0.1)
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
# Collecting feedparser>=5.2.1
#   Using cached feedparser-6.0.8-py3-none-any.whl (81 kB)
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (4.6.1)
# Requirement already satisfied: requests>=2.10.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (2.24.0)
# Collecting tldextract>=2.0.1
#   Using cached tldextract-3.1.2-py2.py3-none-any.whl (87 kB)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (3.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nroy0\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.0.1)
# Requirement already satisfied: six in c:\users\nroy0\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2020.6.20)
# Collecting requests-file>=1.4
#   Using cached requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\nroy0\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.0.12)
# Requirement already satisfied: tqdm in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.50.2)
# Requirement already satisfied: joblib in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (0.17.0)
# Requirement already satisfied: click in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: regex in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2020.10.15)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py): started
#   Building wheel for tinysegmenter (setup.py): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13543 sha256=427e8ed8dae47b67a9b30618ce74abb854cc1c62224b691e6433a2af90dac585
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\99\74\83\8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
#   Building wheel for feedfinder2 (setup.py): started
#   Building wheel for feedfinder2 (setup.py): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3362 sha256=967720d56d699f88bfd466d527e1ce073eadcccb855cb5b24b23365efae64fb4
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\b6\09\68\a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
#   Building wheel for jieba3k (setup.py): started
#   Building wheel for jieba3k (setup.py): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398411 sha256=c1b63251da1dc7205775d2880e18c01e0c42cd87808a027f7ad90c0fc8ff886c
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\1f\7e\0c\54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6070 sha256=4bfd27c8a86b8ec73bdbdc6525321120bb78ec47f3bdc33e3f89e58ab62cfc1c
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\83\63\2f\117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: install, tinysegmenter, cssselect, feedfinder2, sgmllib3k, feedparser, jieba3k, requests-file, tldextract, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-6.0.8 install-1.3.4 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.1.2
# Collecting newspaper3k
#   Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Collecting cssselect>=0.9.2
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (4.6.1)
# Collecting tldextract>=2.0.1
#   Downloading tldextract-3.1.2-py2.py3-none-any.whl (87 kB)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (3.5)
# Collecting feedparser>=5.2.1
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
# Collecting feedfinder2>=0.0.4
#   Using cached feedfinder2-0.0.4.tar.gz (3.3 kB)
# Requirement already satisfied: requests>=2.10.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (2.24.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (4.9.1)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (8.0.1)
# Collecting jieba3k>=0.35.1
#   Using cached jieba3k-0.35.1.zip (7.4 MB)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\nroy0\anaconda3\lib\site-packages (from newspaper3k) (5.3.1)
# Collecting tinysegmenter==0.3
#   Using cached tinysegmenter-0.3.tar.gz (16 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nroy0\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->newspaper3k) (1.15.0)
# Requirement already satisfied: idna in c:\users\nroy0\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.10)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\nroy0\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.0.12)
# Requirement already satisfied: click in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: joblib in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (0.17.0)
# Requirement already satisfied: regex in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2020.10.15)
# Requirement already satisfied: tqdm in c:\users\nroy0\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.50.2)
# Collecting sgmllib3k
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nroy0\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nroy0\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.0.1)
# Building wheels for collected packages: feedfinder2, jieba3k, tinysegmenter, sgmllib3k
#   Building wheel for feedfinder2 (setup.py): started
#   Building wheel for feedfinder2 (setup.py): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3362 sha256=967720d56d699f88bfd466d527e1ce073eadcccb855cb5b24b23365efae64fb4
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\b6\09\68\a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
#   Building wheel for jieba3k (setup.py): started
#   Building wheel for jieba3k (setup.py): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398411 sha256=6037ff84a8f50a046a9db0344de1e48ea456e74e189fd3b0164a22a00c878021
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\1f\7e\0c\54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
#   Building wheel for tinysegmenter (setup.py): started
#   Building wheel for tinysegmenter (setup.py): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13543 sha256=3e309910b1b808f617323b844d9a8be6e670c5c2ffc32e3acaedd4d2bcfd99cb
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\99\74\83\8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6070 sha256=fff79865839ce223a54d2b9d79978b4703fd831e5ee2c800cde22460e0b4af4d
#   Stored in directory: c:\users\nroy0\appdata\local\pip\cache\wheels\83\63\2f\117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built feedfinder2 jieba3k tinysegmenter sgmllib3k
# Installing collected packages: cssselect, requests-file, tldextract, sgmllib3k, feedparser, feedfinder2, jieba3k, tinysegmenter, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-6.0.8 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.1.2

# %% [markdown]
# # Newspaper3k
#
# https://pypi.org/project/newspaper3k/

# %%
from newspaper import Article

url = 'http://fox13now.com/2013/12/30/new-year-new-laws-obamacare-pot-guns-and-drones/'
article = Article(url)

# %%
article.download()

# %%
article.parse()

# %%
article.authors
# Out:
# []

# %%
article.publish_date
# Out:
# datetime.datetime(2013, 12, 30, 0, 0)

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['guns',
#  'state',
#  'leave',
#  'obamacare',
#  'national',
#  'laws',
#  'wage',
#  'minimum',
#  'family',
#  'drones',
#  'law',
#  'pot',
#  'states',
#  'latest']
